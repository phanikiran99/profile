# %%
# Basic imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt

# %matplotlib inline
sns.set()

# %%
# read file
data = pd.read_excel('datafile.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
data.head()
# Out:
#       Year    Country/ State/ UT Name  All Categories - Male  \
# 0  2010-11  Andaman & Nicobar Islands                    9.6
# 1  2010-11             Andhra Pradesh                   32.1
# 2  2010-11          Arunachal Pradesh                   33.6
# 3  2010-11                      Assam                   13.3
# 4  2010-11                      Bihar                   11.8
#
#    All Categories - Female  All Categories - Total  SC - Male  SC - Female  \
# 0                     13.4                    11.4        NaN          NaN
# 1                     24.4                    28.4       29.8         21.9
# 2                     19.5                    26.9      100.0         66.0
# 3                     13.4                    13.4       10.4         12.2
# 4                      9.1                    10.5        7.0          4.7
#
#    SC - Total  ST - Male  ST - Female  ST - Total
# 0         NaN        4.4          8.8         6.6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 11 columns):
# Year                       220 non-null object
# Country/ State/ UT Name    220 non-null object
# All Categories - Male      220 non-null float64
# All Categories - Female    220 non-null float64
# All Categories - Total     220 non-null float64
# SC - Male                  197 non-null float64
# SC - Female                197 non-null float64
# SC - Total                 197 non-null float64
# ST - Male                  190 non-null float64
# ST - Female                190 non-null float64
# ST - Total                 190 non-null float64
# dtypes: float64(9), object(2)
# memory usage: 19.0+ KB

# %%
data.describe()
# Out:
#        All Categories - Male  All Categories - Female  All Categories - Total  \
# count             220.000000               220.000000              220.000000
# mean               23.543182                23.056818               23.238636
# std                10.582846                11.235889               10.576665
# min                 0.000000                 0.000000                0.000000
# 25%                16.600000                14.700000               15.750000
# 50%                22.350000                22.450000               22.500000
# 75%                28.825000                28.500000               28.225000
# max                51.800000                70.400000               57.600000
#
#         SC - Male  SC - Female  SC - Total   ST - Male  ST - Female  \
# count  197.000000   197.000000  197.000000  190.000000   190.000000
# mean    23.936041    22.243147   23.202030   17.387368    15.787895
# ...

# %%
# findout top enrollment year irrespective of state

# %%
data[['Year','All Categories - Male','All Categories - Female','All Categories - Total']].groupby(by='Year').mean().plot(figsize=(10,5),kind='bar')
plt.xlabel('Academic Years')
plt.ylabel('Avg Enrollement %')
plt.title('Total Enrollments Overall')
# Out:
# Text(0,0.5,'Avg Enrollement %')
